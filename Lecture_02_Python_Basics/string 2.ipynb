# %% [markdown]
# Write a program that:
# Asks the user to enter a string
# Prints the first character of the string
# Prints the last character of the string

# %%
s=input("enter a sentence : ")
print(s[0])
print(s[-1])
# Out:
# enter a sentence : kerdolos moheb
# k
# b

# %% [markdown]
# String Length
# Write a program that:
# Asks the user to enter a word
# Prints the length of the word

# %%
s=input("enter a word : ")
print(len(s))
# Out:
# enter a word : kerolos
# 7

# %% [markdown]
# String Methods
# Write a program that:
# Asks the user to enter a text
# Prints the text in uppercase
# Prints the text in lowercase
# Prints the number of characters in the text

# %%
s=input("enter a sentence : ")
print(s.upper())
print(s.lower())
print(len(s))
# Out:
# enter a sentence : kerolos moheb shaker khalil
# KEROLOS MOHEB SHAKER KHALIL
# kerolos moheb shaker khalil
# 27

# %% [markdown]
#  Write a Python Program  that takes a string as input and print the string in reverse order.

# %%
s=input("enter a sentence : ")
print(s[::-1])
# Out:
# enter a sentence : kerolos moheb shaker khlalli
# illalhk rekahs behom solorek
