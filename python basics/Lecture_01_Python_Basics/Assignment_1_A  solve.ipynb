# %% [markdown]
# ## **Assignment Problem (Homework)**
# ### Question 1: Print & Variables
# ## Write a program that:
#
# # Stores your name in a variable
#
# # Stores your age in another variable
#
# # Prints the following sentence using an f-string:
# # Hello, my name is ___ and I am ___ years old

# %%
name = "kerolos"
age = 19
print("hello, my name is", name, "and i am", age, "years old") # اللي خدناها ف السيشن
# Out:
# hello, my name is kerolos and i am 19 years old

# %%
name="kerolos"
age=19
print(f"hello, my name is {name} and i am {age} years old") # using f-string
# Out:
# hello, my name is kerolos and i am 19 years old

# %% [markdown]
# # **🔹 Question 2: Simple Calculator**
# ## Create a Python program that:
#
# ### 1- Asks the user to enter two numbers.
#
# ### 2-Stores them as variables (make sure to convert them to integers).
#
# ### 3-Performs and prints the results of the following operations:
#
# * ## Addition
#
# * ## Subtraction
#
# * ## Multiplication
#
# * ## Division
#
# * ## Power (num1 ** num2)
#
# * ## Modulus (num1 % num2)
#
# * ## Floor division (num1 // num2)

# %%
print("enter two number ,please : ")
num1=int(input("the first num is: "))
num2=int(input("the second num is: "))
sum=num1+y
print("the sum is:" ,sum)

substructor=num1-num2
print("the substructor is:" ,substructor)

multiply=num1*num2
print("the multiply is:" ,multiply)

division=num1/num2
print("the division is:" ,division)

power=num1**num2
print("the power is:" ,power)

modulus=num1%num2
print("the modulus is:" ,modulus)

floor_division=num1//num2
print("the floor division is:" ,floor_division)
# Out:
# enter two number ,please :
# the first num is: 80
# the second num is: 3
# the sum is: 86
# the substructor is: 77
# the multiply is: 240
# the division is: 26.666666666666668
# the power is: 512000
# the modulus is: 2
# the floor division is: 26

# %% [markdown]
# # Question 3
# # Write a Python program that does the following:
#
# # Asks the user to enter the length and width of a rectangle (Float).
#
# # Calculates the area and perimeter of the rectangle(Float).
#
# # Prints the result neatly, for example:
# # Enter length: 5
# # Enter width: 3
# # Area: 15.0
# # Perimeter: 16.0

# %%
print("enter the length and width :")
l=float(input("enter the length :"))
w=float(input("enter the width:"))
area=l*w
print("Area:", area)
perimeter=(l+w)*2
print("perimeter:", perimeter)
# Out:
# enter the length and width :
# enter the length :5
# enter the width:3
# Area: 15.0
# perimeter: 16.0
